# %% [markdown]
# ### <p style="color:red">Part I Project Summary: The big picture </p>

# %% [markdown]
# <b>Write a brief summary of the dataset (at most 3 sentences)</b><br>
# Airbnb'nin yaptığı işe alım yarışması için kullanılan bu dataset, yeni bir kullanıcının ilk rezervasyonunu hangi ülkede yapacağını tahmin etmemiz için hazırlanmıştır. Cevaplarıyla, Airbnb'nin Veri Bilimi ve Analitiği ekibine katılma fırsatı kazanırlar.<br><br>
# <b>Write the aim of the study (at most 3 sentences)</b><br>
#
# Bu çalışmada yeni bir kullanıcının ilk seyahat deneyimlerini nerede rezerve edeceğini doğru bir şekilde bularak, ilk rezervasyon için ortalama süreyi azaltmak amaçlanmaktadır.
#
# <b>Write the Web site address of the datasets </b><br>
#
#  https://www.kaggle.com/c/airbnb-recruiting-new-user-bookings/data
#
#  <b>Write major findings of the analysis (at most 3 sentences) </b><br>
#
#
#
# Bir şeyler yaz
#
# <b>If the data has already been analyzed in a web site and you have benefited from that, write that web site address  </b><br>
#
#
# Bir şeyler yaz

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt;
import warnings
import seaborn   #visualiziation library
# %matplotlib inline 

warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('train_users_2.csv')

# %%
data.shape
# Out:
# (213451, 16)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.head(3)
# Out:
#            id date_account_created  timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28          20090319043255                NaN
# 1  820tgsjxq7           2011-05-25          20090523174809                NaN
# 2  4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
#
#       gender   age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-   NaN      facebook            0       en            direct
# 1       MALE  38.0      facebook            0       en               seo
# 2     FEMALE  56.0         basic            3       en            direct
#
#   affiliate_provider first_affiliate_tracked signup_app first_device_type  \
# 0             direct               untracked        Web       Mac Desktop
# 1             google               untracked        Web       Mac Desktop
# 2             direct               untracked        Web   Windows Desktop
#
#   first_browser country_destination
# ...

# %%
data.dtypes
# Out:
# id                          object
# date_account_created        object
# timestamp_first_active       int64
# date_first_booking          object
# gender                      object
# age                        float64
# signup_method               object
# signup_flow                  int64
# language                    object
# affiliate_channel           object
# affiliate_provider          object
# first_affiliate_tracked     object
# signup_app                  object
# first_device_type           object
# first_browser               object
# country_destination         object
# dtype: object

# %%
#data.drop(["id"],axis=1,inplace=True)

# %%
data.head(3)
# Out:
#            id date_account_created  timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28          20090319043255                NaN
# 1  820tgsjxq7           2011-05-25          20090523174809                NaN
# 2  4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
#
#       gender   age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-   NaN      facebook            0       en            direct
# 1       MALE  38.0      facebook            0       en               seo
# 2     FEMALE  56.0         basic            3       en            direct
#
#   affiliate_provider first_affiliate_tracked signup_app first_device_type  \
# 0             direct               untracked        Web       Mac Desktop
# 1             google               untracked        Web       Mac Desktop
# 2             direct               untracked        Web   Windows Desktop
#
#   first_browser country_destination
# ...

# %%
data.shape
# Out:
# (213451, 16)

# %% [markdown]
# ### <p style="color:red">Part II Dataset Description</p>

# %% [markdown]
# ### Present a description of the dataset

# %% [markdown]
# <b><u>What is it about?</u></b>  <br>
# <li>Dataset yeni kullanıcıların ilk rezervasyonunu nereye yapacağı hakkındadır. <br><br>
# <u><b>How many samples are there?</b></u>  <br>
# <li>213451 adet örnek bulunmaktadır.<br><br>
# <u><b>How many variables are there in your dataset?</b></u>  <br>
# <li>16 adet değişken  bulunmaktadır.<br><br>
# <u><b>What are the types of each of those variables?</b></u>  <br>
#     <li>id:                          object
#    <li>date_account_created:        object
#    <li>timestamp_first_active:       int64
#    <li>date_first_booking:          object
#    <li>gender:                      object
#    <li>age:                        float64
#    <li>signup_method:               object
#    <li>signup_flow:                  int64
#    <li>language:                    object
#    <li>affiliate_channel:           object
#    <li>affiliate_provider:          object
#    <li>first_affiliate_tracked:     object
#    <li>signup_app:                  object
#    <li>first_device_type:           object
#    <li>first_browser:               object
#    <li>country_destination:         object

# %%
print("Örnek Sayısı:",len(data))
print("\nDeğişken Sayısı:",len(data.columns))
print("\nDeğişkenlerin Tipleri:\n",data.dtypes)
# Out:
# Örnek Sayısı: 213451
#
# Değişken Sayısı: 16
#
# Değişkenlerin Tipleri:
#  id                          object
# date_account_created        object
# timestamp_first_active       int64
# date_first_booking          object
# gender                      object
# age                        float64
# signup_method               object
# signup_flow                  int64
# language                    object
# affiliate_channel           object
# affiliate_provider          object
# first_affiliate_tracked     object
# signup_app                  object
# first_device_type           object
# first_browser               object
# country_destination         object
# dtype: object

# %%
#data2=data.iloc[0:10000] # first 10000 rows of data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213451 entries, 0 to 213450
# Data columns (total 16 columns):
# id                         213451 non-null object
# date_account_created       213451 non-null object
# timestamp_first_active     213451 non-null int64
# date_first_booking         88908 non-null object
# gender                     213451 non-null object
# age                        125461 non-null float64
# signup_method              213451 non-null object
# signup_flow                213451 non-null int64
# language                   213451 non-null object
# affiliate_channel          213451 non-null object
# affiliate_provider         213451 non-null object
# first_affiliate_tracked    207386 non-null object
# signup_app                 213451 non-null object
# first_device_type          213451 non-null object
# first_browser              213451 non-null object
# country_destination        213451 non-null object
# dtypes: float64(1), int64(2), object(13)
# ...

# %%
data2=data

# %%
data.shape
# Out:
# (213451, 16)

# %% [markdown]
# ### Data Cleaning

# %%
f = lambda x: np.NaN if x=="-unknown-"  else x
data2['gender'] = data2['gender'].map(f)
data2['first_browser'] = data2['first_browser'].map(f)

# %%
f = lambda x: np.NaN if x=="NDF"  else x
data2.country_destination = data2.country_destination.map(f)

# %%
nulls = data2.isnull().sum()
nulls[nulls > 0]
# Out:
# date_first_booking         124543
# gender                      95688
# age                         87990
# first_affiliate_tracked      6065
# first_browser               27266
# country_destination        124543
# dtype: int64

# %%
data2.dropna(how="any",inplace=True)

# %%
data2.shape
# Out:
# (52321, 16)

# %%
data2.groupby('country_destination').count()[['age']]
# Out:
#                        age
# country_destination
# AU                     354
# CA                     833
# DE                     687
# ES                    1347
# FR                    2904
# GB                    1398
# IT                    1581
# NL                     468
# PT                     127
# US                   36867
# other                 5755

# %%
f = lambda x: np.NaN if x=="other"   else x
data2.country_destination = data2.country_destination.map(f)

# %%
data2=data2.dropna(how="any")

# %%
len(data2)
# Out:
# 46566

# %% [markdown]
# data2.fillna(data2.mean(), inplace=True)
#
# data2.fillna(method='ffill', inplace=True)
#
# data2.fillna(method='bfill', inplace=True)

# %%
nulls2 = data2.isnull().sum()
nulls2[nulls2 > 0]
# Out:
# Series([], dtype: int64)

# %%
from sklearn.preprocessing import LabelEncoder
def convert(data2):
    lb_make = LabelEncoder()
    for i in data2:
        if data2[i].dtypes=="object":
            data2[i] = lb_make.fit_transform(data2[i])
    return data2

# %%
lb_make = LabelEncoder()
data2["timestamp_first_active"] = lb_make.fit_transform(data2["timestamp_first_active"])

# %%
data2=convert(data2)

# %%
data2.head()
# Out:
#        id  date_account_created  timestamp_first_active  date_first_booking  \
# 2    5825                   202                       0                 135
# 6   28197                     0                       1                   0
# 7     487                     1                       2                   5
# 8   12954                     2                       3                 131
# 10  45076                     2                       4                   1
#
#     gender   age  signup_method  signup_flow  language  affiliate_channel  \
# 2        0  56.0              0            3         5                  2
# 6        0  46.0              0            0         5                  3
# 7        0  47.0              0            0         5                  2
# 8        0  50.0              0            0         5                  3
# 10       0  36.0              0            0         5                  3
#
#     affiliate_provider  first_affiliate_tracked  signup_app  \
# ...

# %% [markdown]
# # Part III Basic Descriptive Statistics

# %% [markdown]
# ### Give basic statistical details about each of the variables

# %% [markdown]
# <li>Distribution, range, min, max, percentiles...
# <li>Appropriate visuals (histogram, box plots...)
# <li>Statistics about the missing values (what is the percentage)
# <li>Outliers (how did you identify outliers)

# %%
print("Datayı temizledikten, transform işlemlerinden geçirdiktikten sonraki min max vb. özellikleri\n")
data2.describe()
# Out:
# Datayı temizledikten, transform işlemlerinden geçirdiktikten sonraki min max vb. özellikleri
#                  id  date_account_created  timestamp_first_active  \
# count  46566.000000          46566.000000            46566.000000
# mean   23282.500000           1143.983314            23282.500000
# std    13442.590654            318.075361            13442.590654
# min        0.000000              0.000000                0.000000
# 25%    11641.250000            919.000000            11641.250000
# 50%    23282.500000           1203.000000            23282.500000
# 75%    34923.750000           1415.000000            34923.750000
# max    46565.000000           1557.000000            46565.000000
#
#        date_first_booking        gender           age  signup_method  \
# count        46566.000000  46566.000000  46566.000000   46566.000000
# mean          1166.451231      0.459026     48.811665       0.400893
# std            333.058066      0.503895    154.279035       0.490260
# ...

# %%
import seaborn as sn
plt.figure(figsize=(15,15))
sn.boxplot(x="country_destination",y="age",data=data2)

# %%
data.age.describe()
# Out:
# count    52321.000000
# mean        48.951052
# std        154.993836
# min          2.000000
# 25%         28.000000
# 50%         33.000000
# 75%         42.000000
# max       2014.000000
# Name: age, dtype: float64

# %% [markdown]
# Age için outlier nokta çıkarma
#
# Q3-Q1=QR
#
# Q3 + (1.5 * QR) = 63

# %%
f = lambda x: np.NaN if x>63   else x
data2.age = data2.age.map(f)

# %%
data2=data2.dropna(how="any")

# %%
len(data2)
# Out:
# 44431

# %%
plt.figure(figsize=(7,7))
sn.boxplot(x="country_destination",y="age",data=data2)

# %%
plt.figure(figsize=(7,7))
sn.boxplot(x="country_destination",y="date_first_booking",data=data2)

# %%
plt.figure(figsize=(7,7))
sn.boxplot(x="country_destination",y="date_account_created",data=data2)

# %%
plt.figure(figsize=(7,7))
sn.boxplot(x="country_destination",y="first_browser",data=data2)

# %%
data2.corr()
# Out:
#                                id  date_account_created  \
# id                       1.000000             -0.002175
# date_account_created    -0.002175              1.000000
# timestamp_first_active  -0.003311              0.962637
# date_first_booking      -0.002002              0.960589
# gender                  -0.006678              0.006285
# age                      0.001719             -0.091522
# signup_method            0.006153             -0.044972
# signup_flow              0.001593              0.032993
# language                -0.000432              0.019585
# affiliate_channel        0.001330              0.034720
# affiliate_provider      -0.003777              0.047023
# first_affiliate_tracked -0.005794             -0.047202
# signup_app              -0.005110              0.031127
# first_device_type       -0.000121              0.044413
# first_browser            0.008076             -0.002716
# country_destination      0.003846              0.044149
#
# ...

# %%
corr = data2.corr()
plt.figure(figsize=(10,10))
p = sn.heatmap(data = corr, square=True , annot=True, cbar=True)

# %%
sn.pairplot(data2)

# %%
x = [data2['country_destination']]
g1counts= data2['country_destination'].value_counts()
g1labels = g1counts.axes[0].tolist()
num_bins = len(g1labels)
n, bins, patches = plt.hist(x, num_bins, facecolor='blue', alpha=0.5)
plt.xlabel('Country')
plt.ylabel('')
plt.title(r'Ülkelere göre dağılım histogramı')
plt.show()

# %%
plt.figure(figsize=(5,5))
sn.kdeplot(data2['age'], shade=True , color='r')

# %%
plt.figure(figsize=(7,7))
sn.kdeplot(data2['country_destination'], shade=True , color='r')

# %%
plt.figure(figsize=(7,7))
sn.kdeplot(data2['first_browser'], shade=True , color='r')

# %%
plt.figure(figsize=(7,7))
sn.kdeplot(data2['date_first_booking'] , shade=True , color='g')

# %%
p = data2.hist(figsize = (20,20.27),bins=100)

# %%
data2.describe()
# Out:
#                  id  date_account_created  timestamp_first_active  \
# count  44431.000000          44431.000000            44431.000000
# mean   23291.568544           1144.751300            23317.541109
# std    13450.913589            317.892439            13456.023652
# min        0.000000              0.000000                0.000000
# 25%    11621.500000            920.000000            11664.500000
# 50%    23307.000000           1203.000000            23320.000000
# 75%    34947.500000           1416.000000            34985.500000
# max    46565.000000           1557.000000            46565.000000
#
#        date_first_booking        gender           age  signup_method  \
# count        44431.000000  44431.000000  44431.000000   44431.000000
# mean          1167.760460      0.459544     35.075420       0.408881
# std            333.031237      0.504114      9.493317       0.491816
# min              0.000000      0.000000      2.000000       0.000000
# ...

# %%
def outlierRemover(df):
    for i in df.describe().columns:
        Q1 = df.describe().at['25%',i]
        Q3 = df.describe().at['75%',i]
        IQR = Q3 - Q1
        LTV = Q1 - 1.5 * IQR
        UTV = Q3 + 1.5 * IQR
        x = np.array(df[i])
        p = []
        for j in x:
            if j <= LTV or j >= UTV:
                p.append(df[i].median())
            else:
                p.append(j)     
        df[i] = p
    return df

# %%
data2.head(10)

# %%
data3 = data2.copy()
outlierRemover(data3).describe()

# %%
data3.head(10)

# %% [markdown]
# <b>Explain all the data management steps (data preprocessing steps) clearly   </b>
#
# <li>Does your data come from separate files? If so, how did you merge them?</li>
# __ verilerimiz tek bir dosyadan gelmektedir. <br><br>
#
# <li>How did you handle missing values?</li>
# __ Kayıp değerleri age kolonu için ortalamayı kullanarak diğer kolonlarda ise backward ve forward ile doldurduk. <br><br>
#
# <li>How did you handle outliers?  </li>
#
# <li>Did you apply any data transformation method? </li>
# __ Objeleri LabelEncoder yardımıyla fit_transform işleminden geçirerek sayısal değere dönüştürülmesi sağlanıldı.  <br><br>
#
# <li>Did you apply any scaling method?</li>

# %%
X= data2[data2.columns[data2.columns!= 'country_destination']]
y= data2['country_destination']

# %%
p = sn.factorplot(x='age', data=data2 , kind='count',aspect=1)

# %%
p = sn.factorplot(x='country_destination', data=data2 , kind='count',aspect=1)

# %%
p = sn.factorplot(x='gender', data=data2 , kind='count',aspect=1)

# %%
p = sn.factorplot(x='signup_method', data=data2 , kind='count',aspect=1)

# %%
p = sn.factorplot(x='language', data=data2 , kind='count',aspect=1)

# %%
p = sn.factorplot(x='first_browser', data=data2 , kind='count',aspect=1)

# %%
import statsmodels.formula.api as smf

lm = smf.ols(formula='country_destination ~ date_account_created + timestamp_first_active + date_first_booking +gender+age+signup_method+signup_flow+language+affiliate_channel+affiliate_provider+first_affiliate_tracked+signup_app+first_device_type+first_browser' ,data=data2).fit() #multivarable yapıyor

# print the coefficients
lm.params
# Out:
# Intercept                  7.873119
# date_account_created      -0.000610
# timestamp_first_active     0.000006
# date_first_booking         0.000643
# gender                     0.042383
# age                       -0.002005
# signup_method              0.025040
# signup_flow                0.006189
# language                   0.026788
# affiliate_channel         -0.036757
# affiliate_provider         0.025585
# first_affiliate_tracked   -0.010606
# signup_app                -0.077195
# first_device_type          0.012259
# first_browser             -0.006361
# dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0,test_size=0.2)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn import datasets
from IPython.display import Image  
from sklearn import tree
import pydotplus
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC

# %%
clf = GaussianNB()
clf.fit(X_train, y_train) 
clf.score(X_test,y_test)
# Out:
# 0.7856419489141443

# %% [markdown]
# # Part V Data Visualization

# %% [markdown]
# <b>Visualize   your   data   using   proper   visualization   techniques   and explain</b>
#
# <li>The  relationship  between  each  pair  of  the  variables  is properly visualized
#
# <li>The  relationship  between  each  of  the  variables  and  the response    variables    is    visualized
#
# (choose    the    best visualization technique)

# %%
import statsmodels.formula.api as smf 
reg = smf.ols('country_destination ~ date_account_created + timestamp_first_active + date_first_booking + gender + age + signup_method + signup_flow + language + affiliate_channel + affiliate_provider + first_affiliate_tracked + signup_app + first_device_type + first_browser', data=data2).fit()
print (reg.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     country_destination   R-squared:                       0.005
# Model:                             OLS   Adj. R-squared:                  0.005
# Method:                  Least Squares   F-statistic:                     16.95
# Date:                 Fri, 17 May 2019   Prob (F-statistic):           1.58e-42
# Time:                         11:41:57   Log-Likelihood:                -97772.
# No. Observations:                44431   AIC:                         1.956e+05
# Df Residuals:                    44416   BIC:                         1.957e+05
# Df Model:                           14
# Covariance Type:             nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   7.8731      0.136     58.045      0.000       7.607       8.139
# ...

# %%
# En çok ve en az gidilen ülke sayısı
ct_min = data2['country_destination'].min()
ct_max = data2['country_destination'].max()

# %%
print(ct_max ,ct_min)
# Out:
# 9 0

# %% [markdown]
# # Part VI Machine Learning (ML) Implementation: Model Selection and Evaluation

# %% [markdown]
# ##### Which type of ML method have you used? (Regression/Classification or Clustering?)

# %% [markdown]
# #  <center>Multiple Classification

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0,test_size=0.2)

# %% [markdown]
# ### Decision Trees

# %%
clf = tree.DecisionTreeClassifier().fit(X_train, y_train) 
y_pred = clf.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.6183188927647125

# %%
tree_clf = DecisionTreeClassifier(max_depth=2,max_features =True, random_state=42).fit(X_train,y_train)
y_pred = tree_clf.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7941937661753122

# %%
# training a DescisionTreeClassifier 
from sklearn.tree import DecisionTreeClassifier 
dtree_model = DecisionTreeClassifier(max_depth = 2).fit(X_train, y_train) 
dtree_predictions = dtree_model.predict(X_test) 
accuracy_score(y_test, dtree_predictions)
# Out:
# 0.7941937661753122

# %% [markdown]
# ### Support Vector Machines

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0,test_size=0.2)

# %%
svc_clf = SVC(C=5).fit(X_train, y_train)
y_pred = svc_clf.predict(X_test)
accuracy_score(y_test, y_pred)

# %%
kernels = [ "poly"]
for kernel in kernels:
    svc = SVC(kernel=kernel).fit(X_train,y_train)
    y_pred = svc.predict(X_test)
    print(accuracy_score(y_test, y_pred))
    #plotSVC("kernel=" + str(kernel))

# %%
svm_clf= SVC()
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)

cv_scores = cross_val_score(svm_clf, X_train_scaled, y_train)
print('Cross-validation scores (3-fold):', cv_scores)
print('Mean cross-validation score (3-fold): {:.3f}'
     .format(np.mean(cv_scores)))

# %%
svm_clf = Pipeline([
        ("scaler", MinMaxScaler()),
        ("linear_svc", SVC()),
    ])

cv_scores = cross_val_score(svm_clf, X_train, y_train)
print('Cross-validation scores (3-fold):', cv_scores)
print('Mean cross-validation score (3-fold): {:.3f}'
     .format(np.mean(cv_scores)))

# %%
s_clf = SVC(kernel='rbf', random_state=11, gamma=.01, C=1)
s_clf.fit(X2_train,y2_train)
s_prediction = s_clf.predict(X2_test)
accuracy_score(y2_test,s_prediction)

# %% [markdown]
# ### K-Nearest Neighbors

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0,test_size=0.2)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 5).fit(X_train, y_train)

# %%
y_pred = knn.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7692134578597952

# %% [markdown]
# ### RandomForest

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0,test_size=0.2)

# %%
rfc = RandomForestClassifier().fit(X_train, y_train)

# %%
y_pred = rfc.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7815910881062226

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0,test_size=0.2)

clf = RandomForestClassifier(n_estimators=10, max_depth=None,min_samples_split=2).fit(X_train, y_train)

y_pred = clf.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7829413750421965

# %%
clf2 = RandomForestClassifier(n_estimators = 700,
                            max_features="auto").fit(X_train, y_train)
y_pred = clf2.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7943062900866434

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0,test_size=0.2)
predictions = rf.predict(X_test)
score = round(accuracy_score(y_test, predictions), 3)
cm1 = cm(y_test, predictions)
sns.heatmap(cm1, annot=True, fmt=".0f")
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.title('Accuracy Score: {0}'.format(score), size = 15)
plt.show()

# %% [markdown]
# # GridSearch

# %%
param_grid = {
    'n_estimators': [200, 700],
    'max_features': ['auto', 'sqrt', 'log2']
}
grid_search_cv = GridSearchCV(estimator=clf,  
                     param_grid=param_grid,
                     scoring='accuracy',
                     cv=5,
                     n_jobs=-1)

# Train the classifier on data's feature =X and target data =y
grid_search_cv = grid_search_cv.fit(X_train,y_train)
y_pred = grid_search_cv.predict(X_test)
accuracy_score(y_test, y_pred)

# %%
#Libraries to Build Ensemble Model : Random Forest Classifier 
# Create the parameter grid based on the results of random search 
params_grid = [{'kernel': ['rbf'],
                     'C': [1, 10]},
                    {'kernel': ['linear'], 'C': [1, 10]}]

# %%
from sklearn.model_selection import GridSearchCV

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0,test_size=0.2)

param_range = [0.001, 0.01]
parameters = [{'C': param_range, 'kernel': ['rbf'], 'gamma': [0.1, 0.2]}]
grid_search = GridSearchCV(estimator = s_clf,
                           param_grid = parameters,
                           scoring = 'accuracy', #Puanlamayı doğruluğa göre yap
                           n_jobs = -1) # -1 bütün çekirdekleri kullan
grid_search = grid_search.fit(X_train, y_train)
best_accuracy = grid_search.best_score_
best_parameters = grid_search.best_params_
best_parameters

# %%
# Performing CV to tune parameters for best SVM fit 
svm_model = GridSearchCV(SVC(), params_grid, cv=5,n_jobs=-1).fit(X_train,y_train)
y_pred = svm_model.predict(X_test)
accuracy_score(y_test, y_pred)

# %%
gs = GridSearchCV(DecisionTreeClassifier(random_state=42),
                  param_grid={'min_samples_split': range(2, 403, 10)},
                  scoring=scoring, cv=5, refit='AUC', return_train_score=True,n_jobs=-1
                 )
gs.fit(X_train, y_train)
results = gs.cv_results_

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB 
from sklearn.metrics import confusion_matrix 

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0,test_size=0.2)
gnb = GaussianNB().fit(X_train, y_train)
y_pred = gnb.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7856419489141443

# %% [markdown]
# # Veriyi Eğitim ve Test Olarak Ayırmak

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# # Normalizasyon – Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X2_train = sc_X.fit_transform(X2_train)
X2_test = sc_X.transform(X2_test)

# %% [markdown]
# # Naive Bayes Modeli Oluşturmak ve Eğitmek

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X2_train, y2_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %% [markdown]
# # Test Seti ile Tahmin Yapmak

# %%
y2_pred = classifier.predict(X2_test)
accuracy_score(y2_test, y2_pred)
# Out:
# 0.7772026555643075

# %% [markdown]
# # Bagging Algorithms

# %%
from sklearn import model_selection
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

kfold = model_selection.KFold(n_splits=10, random_state=42)
cart = DecisionTreeClassifier()
num_trees = 100
model = BaggingClassifier(base_estimator=cart, n_estimators=num_trees, random_state=42)
results = model_selection.cross_val_score(model, X_train, y_train, cv=kfold)
print(results.mean())
# Out:
# 0.7925665896551262

# %% [markdown]
# # Voting Ensemble

# %%
from sklearn.ensemble import VotingClassifier

kfold = model_selection.KFold(n_splits=10, random_state=42)
# create the sub models
estimators = []

model2 = DecisionTreeClassifier()
estimators.append(('cart', model2))
model3 = SVC()
estimators.append(('svm', model3))
# create the ensemble model
ensemble = VotingClassifier(estimators)
results = model_selection.cross_val_score(ensemble, X_train, y_train, cv=kfold)
print(results.mean())

# %% [markdown]
# # RFECV Sonrası

# %%
from sklearn import linear_model
from sklearn.feature_selection import RFECV

regr = linear_model.LinearRegression()

rfecv = RFECV(estimator=regr, cv=5, scoring='r2').fit(X, y)
print("Optimal number of features : %d" % rfecv.n_features_)
print(rfecv.support_)
print(rfecv.grid_scores_)

# %%
plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Cross validation score")
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_)
plt.show()

# %%
np.absolute(rfecv.estimator_.coef_)

# %%
from sklearn.feature_selection import RFECV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier

# %%
# fit a linear_model.PassiveAggressiveClassifier() model to the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
model = linear_model.RidgeClassifier(normalize=True)
model.fit(X_train, y_train)
print(); print(model)
    
y_pred = gnb.predict(X_test)
accuracy_score(y_test, y_pred)

# %% [markdown]
# # Temiz olmayan datayla

# %%
X2= data2[data2.columns[data2.columns!= 'country_destination']]
y2= data2['country_destination']
X_train, X_test, y_train, y_test = train_test_split(X2, y2, random_state=0,test_size=0.2)

gnb = GaussianNB().fit(X_train, y_train)
y_pred = gnb.predict(X_test)
accuracy_score(y_test, y_pred)

# %% [markdown]
# # Sonuçlar

# %%
testData = data2.copy()
country_title = list()
for gData in testData.values:
    if gData[9] > 7.:
        country_title.append("Çok Gidilen")
    elif gData[9] > 4 and gData[9] <7:
        country_title.append("Arada Gidilen")
    else:
        country_title.append("Az Gidilen")

country_title_frame = pd.DataFrame(np.array(country_title),columns=['country_destination'])
testData.reset_index(drop=True, inplace=True)
country_title_frame.reset_index(drop=True, inplace=True)
testData = pd.concat([testData, country_title_frame],axis=1)

# %%
data2

# %% [markdown]
# Veri tiplerini kontrol etme/düzeltme.
#
# Açıklayıcı veri analizi ve görselleştirme.
#
# Eksik verileri tahmin etme/veri atama.
#
# Kategori tipindeki verileri nümerik formata çevirme.
#
# Veri setini eğitim ve test veri-setlerine ayırma.
#
# Modeli eğitme ve test verisi üzerinde tahmin yapma.
#
# Sınıflandırma başarı metriklerine bakma.
